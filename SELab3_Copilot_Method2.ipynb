# %% [markdown]
# <a href="https://colab.research.google.com/github/junaidstudents-se/SE-CW/blob/SELab3/SELab3_Copilot_Method2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone -b SELab3 https://github.com/junaidstudents-se/SE-CW.git
# Out:
# Cloning into 'SE-CW'...
# remote: Enumerating objects: 127, done.
# remote: Counting objects: 100% (127/127), done.
# remote: Compressing objects: 100% (107/107), done.
# remote: Total 127 (delta 57), reused 11 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (127/127), 48.00 KiB | 792.00 KiB/s, done.
# Resolving deltas: 100% (57/57), done.

# %%
# !ls
# Out:
# sample_data  SE-CW

# %%
# %cd SE-CW
# Out:
# /content/SE-CW

# %%
# %cd SELab1/
# Out:
# /content/SE-CW/SELab1

# %%
# !ls
# Out:
# calculator.py  requirements.txt  test_calculator1.py
# README.md      student-task.md	 test_calculator.py

# %%
# !python calculator.py
# Out:
# ...
#        ENHANCED SIMPLE CALCULATOR
#     Software Engineering Lab 01
# ...
#
# Select an operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# 6. Power
# 7. Square Root
# 8. Factorial
# 9. Exit
#
# Enter your choice (1-9): 7
# Enter number: 49
#
# Result: 7.0
#
# Select an operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# 6. Power
# 7. Square Root
# 8. Factorial
# 9. Exit
#
# Enter your choice (1-9): 8
# Enter number: 7
# Error: Factorial requires a non-negative integer.
#
# Select an operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# 6. Power
# 7. Square Root
# 8. Factorial
# 9. Exit
#
# Enter your choice (1-9): 7!
# Invalid choice. Please select 1-9.
#
# Select an operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# 6. Power
# 7. Square Root
# 8. Factorial
# 9. Exit
#
# Enter your choice (1-9): 8
# Enter number: 7!
# ...

# %% [markdown]
# Error in Factorial

# %%
# !git clone -b SELab3 https://github.com/junaidstudents-se/SE-CW.git
# Out:
# Cloning into 'SE-CW'...
# remote: Enumerating objects: 180, done.
# remote: Counting objects: 100% (180/180), done.
# remote: Compressing objects: 100% (160/160), done.
# remote: Total 180 (delta 82), reused 11 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (180/180), 88.80 KiB | 8.07 MiB/s, done.
# Resolving deltas: 100% (82/82), done.

# %%
# %cd SE-CW//SELab1/
# Out:
# /content/SE-CW/SELab1

# %%
# !ls
# Out:
# calculator.py		 INDEX.md	     test_calculator1.py
# COMPLETION_CHECKLIST.md  PROJECT_SUMMARY.md  test_calculator.py
# demo.py			 README.md	     TEST_REPORT.md
# DEVELOPMENT_GUIDE.md	 requirements.txt
# FINAL_STATUS_REPORT.md	 student-task.md

# %%
# !python calculator.py
# Out:
# ...
#        ENHANCED SIMPLE CALCULATOR
#     Software Engineering Lab 01
# ...
#
# Select an operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# 6. Power
# 7. Square Root
# 8. Factorial
# 9. Exit
#
# Enter your choice (1-9): 8
# Enter number: 7
#
# Result: 5040
#
# Select an operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# 6. Power
# 7. Square Root
# 8. Factorial
# 9. Exit
#
# Enter your choice (1-9): 5
# Enter first number: 7
# Enter second number: 7
#
# Result: 0.0
#
# Select an operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# 6. Power
# 7. Square Root
# 8. Factorial
# 9. Exit
#
# Enter your choice (1-9): 5
# Enter first number: 14
# Enter second number: 7
#
# Result: 0.0
#
# Select an operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# 6. Power
# 7. Square Root
# 8. Factorial
# 9. Exit
#
# Enter your choice (1-9): 6
# ...
