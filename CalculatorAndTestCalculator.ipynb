# %% [markdown]
# <a href="https://colab.research.google.com/github/junaidstudents-se/SE-CW/blob/main/CalculatorAndTestCalculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/junaidstudents-se/SE-CW.git
# Out:
# Cloning into 'SE-CW'...
# remote: Enumerating objects: 51, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 51 (delta 11), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (51/51), 15.89 KiB | 5.30 MiB/s, done.
# Resolving deltas: 100% (11/11), done.

# %%
# !ls
# Out:
# sample_data  SE-CW

# %%
# %cd SE-CW/SELab1
# Out:
# /content/SE-CW/SELab1

# %%
# !ls
# Out:
# Calculator.py  README.md  requirements.txt  student-task.md  test_calculator.py

# %%
# !pip install -r requirements.txt

# %%
# !python calculator.py
# Out:
# python3: can't open file '/content/SE-CW/SELab1/calculator.py': [Errno 2] No such file or directory

# %%
# !python Calculator.py
# Out:
# ...
#        SOFTWARE ENGINEERING
#           SIMPLE CALCULATOR
# ...
#
# Select an operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
#
# Enter your choice (1-5): Traceback (most recent call last):
#   File "/content/SE-CW/SELab1/Calculator.py", line 93, in <module>
#     calculator()
#     ~~~~~~~~~~^^
#   File "/content/SE-CW/SELab1/Calculator.py", line 55, in calculator
#     choice = input("\nEnter your choice (1-5): ")
# KeyboardInterrupt
# ^C

# %%
# %run Calculator.py
# Out:
# ...
#        SOFTWARE ENGINEERING
#           SIMPLE CALCULATOR
# ...
#
# Select an operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
#
# Enter your choice (1-5): 4
# Enter first number: 6
# Enter second number: 3
#
# Result: 2.0
#
# Select an operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
#
# Enter your choice (1-5): 5
#
# Thank you for using the calculator.

# %%
# !pytest
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.13.15, pytest-8.4.2, pluggy-1.6.0
# rootdir: /content/SE-CW/SELab1
# plugins: langsmith-0.11.0, anyio-4.14.2, typeguard-4.6.0
# collected 0 items / 1 error
#
# ==================================== ERRORS ====================================
# _____________________ ERROR collecting test_calculator.py ______________________
# ImportError while importing test module '/content/SE-CW/SELab1/test_calculator.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# /usr/lib/python3.13/importlib/__init__.py:88: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# test_calculator.py:10: in <module>
#     from calculator import add
# E   ModuleNotFoundError: No module named 'calculator'
# ...

# %%
# !pytest
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.13.15, pytest-8.4.2, pluggy-1.6.0
# rootdir: /content/SE-CW/SELab1
# plugins: langsmith-0.11.0, anyio-4.14.2, typeguard-4.6.0
# collected 0 items / 1 error
#
# ==================================== ERRORS ====================================
# _____________________ ERROR collecting test_calculator.py ______________________
# ImportError while importing test module '/content/SE-CW/SELab1/test_calculator.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# /usr/lib/python3.13/importlib/__init__.py:88: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# test_calculator.py:10: in <module>
#     from calculator import add
# E   ModuleNotFoundError: No module named 'calculator'
# ...

# %%
# !pytest
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.13.15, pytest-8.4.2, pluggy-1.6.0
# rootdir: /content/SE-CW/SELab1
# plugins: langsmith-0.11.0, anyio-4.14.2, typeguard-4.6.0
# collected 0 items / 1 error
#
# ==================================== ERRORS ====================================
# _____________________ ERROR collecting test_calculator.py ______________________
# ImportError while importing test module '/content/SE-CW/SELab1/test_calculator.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# /usr/lib/python3.13/importlib/__init__.py:88: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# test_calculator.py:10: in <module>
#     from calculator import add
# E   ModuleNotFoundError: No module named 'calculator'
# ...

# %%
# !python -m pytest test_calculator.py -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.13.15, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/SE-CW/SELab1
# plugins: langsmith-0.11.0, anyio-4.14.2, typeguard-4.6.0
# collected 0 items / 1 error
#
# ==================================== ERRORS ====================================
# _____________________ ERROR collecting test_calculator.py ______________________
# ImportError while importing test module '/content/SE-CW/SELab1/test_calculator.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# /usr/lib/python3.13/importlib/__init__.py:88: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# test_calculator.py:10: in <module>
#     from calculator import add
# E   ModuleNotFoundError: No module named 'calculator'
# ...

# %%
# !python -m pytest test_calculator.py -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.13.15, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/SE-CW/SELab1
# plugins: langsmith-0.11.0, anyio-4.14.2, typeguard-4.6.0
# collected 0 items / 1 error
#
# ==================================== ERRORS ====================================
# _____________________ ERROR collecting test_calculator.py ______________________
# ImportError while importing test module '/content/SE-CW/SELab1/test_calculator.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# /usr/lib/python3.13/importlib/__init__.py:88: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# test_calculator.py:10: in <module>
#     from calculator import add
# E   ModuleNotFoundError: No module named 'calculator'
# ...

# %%
# !python -m pytest test_calculator.py -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.13.15, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/SE-CW/SELab1
# plugins: langsmith-0.11.0, anyio-4.14.2, typeguard-4.6.0
# collected 0 items / 1 error
#
# ==================================== ERRORS ====================================
# _____________________ ERROR collecting test_calculator.py ______________________
# ImportError while importing test module '/content/SE-CW/SELab1/test_calculator.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# /usr/lib/python3.13/importlib/__init__.py:88: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# test_calculator.py:10: in <module>
#     from calculator import add
# E   ModuleNotFoundError: No module named 'calculator'
# ...
