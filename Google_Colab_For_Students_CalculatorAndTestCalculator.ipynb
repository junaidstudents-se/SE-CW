# %% [markdown]
# <a href="https://colab.research.google.com/github/junaidstudents-se/SE-CW/blob/main/Google_Colab_For_Students_CalculatorAndTestCalculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/junaidstudents-se/SE-CW.git
# Out:
# Cloning into 'SE-CW'...
# remote: Enumerating objects: 103, done.
# remote: Counting objects: 100% (103/103), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 103 (delta 42), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (103/103), 32.91 KiB | 5.49 MiB/s, done.
# Resolving deltas: 100% (42/42), done.

# %%
# !ls
# Out:
# sample_data  SE-CW

# %%
# %cd SE-CW/SELab1
# Out:
# /content/SE-CW/SELab1/SE-CW/SELab1

# %%
# !ls
# Out:
# calculator.py  requirements.txt  test_calculator1.py
# README.md      student-task.md	 test_calculator.py

# %%
# !pip install -r requirements.txt

# %%
# !python calculator.py
# Out:
# ...
#        SOFTWARE ENGINEERING Syed Muhammad Junaid Hassan
#           SIMPLE CALCULATOR 15741
# ...
#
# Select an operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
#
# Enter your choice (1-5):

# %%
# !pytest
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.13.15, pytest-8.4.2, pluggy-1.6.0
# rootdir: /content/SE-CW/SELab1
# plugins: langsmith-0.11.0, anyio-4.14.2, typeguard-4.6.0
# collected 18 items
#
# test_calculator.py F...F..                                               [ 38%]
# test_calculator1.py F...FFFFFF.                                          [100%]
#
# =================================== FAILURES ===================================
# ___________________________________ test_add ___________________________________
#
#     def test_add():
# >       assert add(10, 5) == 15
# E       assert 5 == 15
# E        +  where 5 = add(10, 5)
#
# test_calculator.py:17: AssertionError
# __________________________ test_add_negative_numbers ___________________________
#
#     def test_add_negative_numbers():
# >       assert add(-10, -5) == -15
# E       assert -5 == -15
# E        +  where -5 = add(-10, -5)
#
# ...
