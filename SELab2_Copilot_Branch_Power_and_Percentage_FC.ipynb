# %% [markdown]
# <a href="https://colab.research.google.com/github/junaidstudents-se/SE-CW/blob/copilot%2Fadd-power-percentage-operations/SELab2_Copilot_Branch_Power_and_Percentage_FC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone -b copilot/add-power-percentage-operations https://github.com/junaidstudents-se/SE-CW.git
# Out:
# Cloning into 'SE-CW'...
# remote: Enumerating objects: 112, done.
# remote: Counting objects: 100% (112/112), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 112 (delta 48), reused 8 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (112/112), 38.58 KiB | 2.14 MiB/s, done.
# Resolving deltas: 100% (48/48), done.

# %%
# !ls
# Out:
# sample_data  SE-CW

# %%
# %cd SE-CW
# Out:
# /content/SE-CW

# %%
# !ls
# Out:
# calculatorandtestcalculator1.ipynb			     HelloSE.ipynb
# CalculatorAndTestCalculator.ipynb			     README.md
# Calculator.ipynb					     SELab1
# Google_Colab_For_Students_CalculatorAndTestCalculator.ipynb

# %%
# %cd SELab1/
# Out:
# /content/SE-CW/SELab1

# %%
# !ls
# Out:
# calculator.py  requirements.txt  test_calculator1.py
# README.md      student-task.md	 test_calculator.py

# %%
# !python calculator.py5
# Out:
# ...
#        SOFTWARE ENGINEERING Syed Muhammad Junaid Hassan
#           SIMPLE CALCULATOR 15741
# ...
#
# Select an operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
#
# Enter your choice (1-5): 5
#
# Thank you for using the calculator.

# %% [markdown]
# The menu does not show power and exponent functions

# %%
# !git clone -b copilot/add-power-percentage-operations https://github.com/junaidstudents-se/SE-CW.git
# Out:
# Cloning into 'SE-CW'...
# remote: Enumerating objects: 120, done.
# remote: Counting objects: 100% (120/120), done.
# remote: Compressing objects: 100% (97/97), done.
# remote: Total 120 (delta 52), reused 16 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (120/120), 45.27 KiB | 2.38 MiB/s, done.
# Resolving deltas: 100% (52/52), done.

# %%
# %cd SE-CW/SELab1/
# Out:
# /content/SE-CW/SELab1/SE-CW/SELab1

# %%
# !ls
# Out:
# calculator.py  README.md	 student-task.md      test_calculator.py
# __pycache__    requirements.txt  test_calculator1.py

# %%
# !python calculator.py5
# Out:
# ...
#        SOFTWARE ENGINEERING Syed Muhammad Junaid Hassan
#           SIMPLE CALCULATOR 15741
# ...
#
# Select an operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Power
# 6. Percentage
# 7. Exit
#
# Enter your choice (1-7): 5
# Enter first number: 2
# Enter second number: 3
#
# Result: 8.0
#
# Select an operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Power
# 6. Percentage
# 7. Exit
#
# Enter your choice (1-7): 6
# Enter first number: 1000
# Enter second number: 10
#
# Result: 100.0
#
# Select an operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Power
# 6. Percentage
# 7. Exit
#
# Enter your choice (1-7): 7
#
# Thank you for using the calculator.
