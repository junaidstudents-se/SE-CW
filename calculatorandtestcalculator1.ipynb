# %% [markdown]
# <a href="https://colab.research.google.com/github/junaidstudents-se/SE-CW/blob/main/calculatorandtestcalculator1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/junaidstudents-se/SE-CW.git
# Out:
# Cloning into 'SE-CW'...
# remote: Enumerating objects: 64, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 64 (delta 19), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (64/64), 21.50 KiB | 1.02 MiB/s, done.
# Resolving deltas: 100% (19/19), done.

# %%
# !ls
# Out:
# sample_data  SE-CW

# %%
# %cd SE-CW/SELab1
# Out:
# /content/SE-CW/SELab1

# %%
# !ls
# Out:
# calculator.py  README.md  requirements.txt  student-task.md  test_calculator.py

# %%
# !python calculator.py
# Out:
# ...
#        SOFTWARE ENGINEERING
#           SIMPLE CALCULATOR
# ...
#
# Select an operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
#
# Enter your choice (1-5): 4
# Enter first number: 3
# Enter second number: 5
#
# Result: 0.6
#
# Select an operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
#
# Enter your choice (1-5): 5
#
# Thank you for using the calculator.

# %%
# !pip install -r requirements.txt

# %%
# !pytest
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.13.15, pytest-8.4.2, pluggy-1.6.0
# rootdir: /content/SE-CW/SELab1
# plugins: langsmith-0.11.0, anyio-4.14.2, typeguard-4.6.0
# collected 7 items
#
# test_calculator.py .......                                               [100%]
#
# ============================== 7 passed in 0.03s ===============================

# %%
# !pytest
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.13.15, pytest-8.4.2, pluggy-1.6.0
# rootdir: /content
# plugins: langsmith-0.11.0, anyio-4.14.2, typeguard-4.6.0
# collected 7 items
#
# SE-CW/SELab1/test_calculator.py .......                                  [100%]
#
# ============================== 7 passed in 0.02s ===============================
